# %%
from bs4 import BeautifulSoup
import requests
import re
import numpy as np
import csv  
import pandas as pd
import numpy as np
from selenium import webdriver
import time

# %%
from selenium.webdriver.support.ui import Select

# %%
#Get the soup object from specified url
def getSoup(url):
    try:
        source = requests.get(url).text
        soup = BeautifulSoup(source, 'lxml')
        print(url)
        return soup
    except Exception as e:
        print(e)
        pass

# %%
#Gets name from soup object
def getGameName(soup):
    try:
        if((soup.find(class_ = 'apphub_AppName').get_text()) == None):
            return
        else:
            gameName = soup.find(class_ = 'apphub_AppName').get_text()
            print(gameName)
            return gameName
    except Exception as e:
        print(e)
        pass

# %%
#Gets review from soup object
def getReview(soup):
    try:
        review = soup.find(class_ = 'game_review_summary positive').get_text()
        print(review)
        return review
    except:
        pass

# %%
#Gets date from soup object
def getDate(soup):
    try:
        date = soup.find(class_ = 'date').get_text()
        print(date)
        return date
    except:
        pass

# %%
#Gets developer name from soup object
def developerName(soup):
    try:
        developer = soup.find(href="https://store.steampowered.com/developer/doublefine?snr=1_5_9__2000").get_text()
        return developer
    except:
        pass

# %%
#Gets tags from soup object
def getTags(soup):
    try:
        tags = soup.find_all(class_ = 'app_tag')
        tagArray=[]
        cleanedTag = ''
        for i in tags:
            i.findNext()
            cleanedTag = i.get_text()
            cleanedTag = cleanedTag.replace('\t','')
            cleanedTag = cleanedTag.replace('\n','')
            cleanedTag = cleanedTag.replace('\r','')
            tagArray.append(cleanedTag)
        tagArray.pop()#Scrapper takes the + so we just remove it
        print(tagArray)
        return(tagArray)
    except:
        pass

# %%
#Finding the different href
def getHref(url):
    try:
        soup = getSoup(url)
        links_with_text = [a['href'] for a in soup.find_all('a', href=True) if a.text]
        #print(links_with_text)
        return links_with_text
    except:
        pass

# %%
def getPageInformation(url):
    try:
        soup = getSoup(url)
        try:
            gameName = getGameName(soup)
        except:
            print("no name")
        try:
            getReview(soup)
        except:
            print("no reviews")
        try:
            getDate(soup)
        except:
            print("no date")
        try:
            developerName(soup)
        except:
            print("no developer name")
        try:
            getTags(soup)
        except:
            print("no tags")
            
    except Exception as e:
        print(e)

# %%
getPageInformation('https://store.steampowered.com/app/1530440/Balance_Ball/')
# Out:
# https://store.steampowered.com/app/1530440/Balance_Ball/
# Balance Ball
# Feb 10, 2021
# ['Adventure', 'Simulation', 'Action', 'Arcade', 'Platformer', '3D Platformer', 'Precision Platformer', '3D', 'Third Person', 'Colorful', 'Atmospheric', 'Futuristic', 'Family Friendly', 'Funny', 'Linear', 'Physics', 'Singleplayer', 'Early Access', 'Indie', 'Strategy']

# %%
#Getting all the game links from a specific steam page
url = 'https://store.steampowered.com/search/?term=dota+2'
PATH = 'C:\Program Files (x86)\chromedriver.exe'
driver = webdriver.Chrome(PATH)
driver.get(url)
hrefs = getHref(url)    
#print(hrefs)
f=open('test_file.txt','w')
for ele in hrefs:
    f.write(ele+'\n')
f.close()
driver.quit()
# Out:
# https://store.steampowered.com/search/?term=dota+2

# %%
with open('steam_data.csv', 'a') as csvfile:
    filewriter = csv.writer(csvfile, delimiter=',',quotechar='|', quoting=csv.QUOTE_MINIMAL)
    filewriter.writerow(['Name', 'Review', 'Date', 'Dev name', 'Tags'])

# %%
df3 = pd.read_csv('steam_data.csv')
df3
# Out:
#    Name  Review  Date  Dev name  Tags
# 0  Name  Review  Date  Dev name  Tags

# %%
def ageCheck(driver):
    string1 = 'https://store.steampowered.com/agecheck/'
    if(driver.current_url[0:40] == string1):
        drp=Select(driver.find_element_by_id("ageYear"))
        drp.select_by_visible_text('1995')
        try:
            button = driver.find_element_by_xpath('//*[@id="app_agegate"]/div[1]/div[4]/a[1]')
            #button = driver.find_element_by_class_name("btnv6_blue_hoverfade btn_medium")        
        except:
            button = driver.find_element_by_xpath('//*[@id="app_agegate"]/div[1]/div[3]/a[1]')
        button.click()
    elif(driver.current_url == '#'):
        pass

# %%
for i in range(len(df)):
    try:
        soup = getSoup(df['https://store.steampowered.com/login/?redir=search%2F%3Fterm%3Ddota%2B2&redir_ssl=1&snr=1_7_7_151_global-header'][i])
        url = df['https://store.steampowered.com/login/?redir=search%2F%3Fterm%3Ddota%2B2&redir_ssl=1&snr=1_7_7_151_global-header'][i]
        #soup = getSoup('#')#'https://store.steampowered.com/agecheck/app/340170/')
        #url = '#'#'https://store.steampowered.com/agecheck/app/340170/'
        PATH = 'C:\Program Files (x86)\chromedriver.exe'
        driver = webdriver.Chrome(PATH)
        driver.get(url)
        #print(driver.current_url)
        ageCheck(driver)
        print('hello')
        name = getGameName(soup)
        review = getReview(soup)
        date = getDate(soup)
        developer = developerName(soup)
        tags = getTags(soup)
        print(name)
        print(review)
        print(date)
        print(developer)
        print(tags)
        with open('steam_data.csv', 'a') as csvfile:

        #f=open('steam_data.csv','a')
        #for ele in review:
            filewriter = csv.writer(csvfile, delimiter=',',quotechar='|', quoting=csv.QUOTE_MINIMAL)
            filewriter.writerow([name, review, date, developer, tags])
         #   f.write(ele+'\n')
        #f.close()
        driver.close()
    except:
        pass
        driver.close()
# Out:
# https://store.steampowered.com/app/570/Dota_2/?snr=1_7_7_151_150_1
# hello
# Dota 2
# Mostly Positive
# Jul 9, 2013
# ['Free to Play', 'MOBA', 'Multiplayer', 'Strategy', 'eSports', 'Team-Based', 'Competitive', 'Action', 'Online Co-Op', 'PvP', 'Difficult', 'Co-op', 'RTS', 'Tower Defense', 'Fantasy', 'RPG', 'Character Customization', 'Replay Value', 'Action RPG', 'Simulation']
# Dota 2
# Mostly Positive
# Jul 9, 2013
# None
# ['Free to Play', 'MOBA', 'Multiplayer', 'Strategy', 'eSports', 'Team-Based', 'Competitive', 'Action', 'Online Co-Op', 'PvP', 'Difficult', 'Co-op', 'RTS', 'Tower Defense', 'Fantasy', 'RPG', 'Character Customization', 'Replay Value', 'Action RPG', 'Simulation']
# https://store.steampowered.com/app/1241930/The_Dota_2_Official_Soundtrack/?snr=1_7_7_151_150_1
# hello
# The Dota 2 Official Soundtrack
# Very Positive
# Feb 10, 2020
# ['+']
# The Dota 2 Official Soundtrack
# Very Positive
# Feb 10, 2020
# None
# ['+']
# https://store.steampowered.com/app/652720/The_Dota_2_Remixes_EP/?snr=1_7_7_151_150_1
# hello
# The Dota 2 Remixes EP
# Very Positive
# Feb 10, 2020
# ['Free to Play', 'Strategy', 'Action', 'Soundtrack', 'Electronic Music']
# The Dota 2 Remixes EP
# Very Positive
# Feb 10, 2020
# None
# ['Free to Play', 'Strategy', 'Action', 'Soundtrack', 'Electronic Music']
# https://store.steampowered.com/app/411180/Dota_2_Player_Profiles/?snr=1_7_7_151_150_1
# hello
# Dota 2 Player Profiles
# Very Positive
# Nov 12, 2015
# ['Gaming', 'Free to Play', 'Documentary', 'Episodic', 'MOBA', 'Multiplayer', 'Competitive', 'Action', 'Adventure', 'Movie', 'Casual', 'Family Friendly', 'Strategy', 'Co-op']
# Dota 2 Player Profiles
# Very Positive
# Nov 12, 2015
# None
# ['Gaming', 'Free to Play', 'Documentary', 'Episodic', 'MOBA', 'Multiplayer', 'Competitive', 'Action', 'Adventure', 'Movie', 'Casual', 'Family Friendly', 'Strategy', 'Co-op']
# https://store.steampowered.com/app/1018830/Element_TD_2__Multiplayer_Tower_Defense/?snr=1_7_7_151_150_1
# hello
# Element TD 2 - Multiplayer Tower Defense
# Very Positive
# Feb 28, 2020
# ['Tower Defense', 'Strategy', 'Indie', 'Multiplayer', 'RTS', 'Fantasy', 'Co-op', 'Competitive', 'PvP', 'PvE', 'Team-Based', 'Online Co-Op', 'Singleplayer', '3D', 'Early Access', 'Real Time Tactics', 'Magic', 'Tactical']
# Element TD 2 - Multiplayer Tower Defense
# Very Positive
# Feb 28, 2020
# None
# ['Tower Defense', 'Strategy', 'Indie', 'Multiplayer', 'RTS', 'Fantasy', 'Co-op', 'Competitive', 'PvP', 'PvE', 'Team-Based', 'Online Co-Op', 'Singleplayer', '3D', 'Early Access', 'Real Time Tactics', 'Magic', 'Tactical']
# https://store.steampowered.com/app/629520/Soundpad/?snr=1_7_7_151_150_1
# hello
# Soundpad
# Overwhelmingly Positive
# Nov 9, 2016
# ['Utilities', 'Audio Production', 'Memes', 'Music', 'Software', 'Funny', 'Survival Horror']
# Soundpad
# Overwhelmingly Positive
# Nov 9, 2016
# None
# ['Utilities', 'Audio Production', 'Memes', 'Music', 'Software', 'Funny', 'Survival Horror']
# https://store.steampowered.com/app/469600/Legion_TD_2__Multiplayer_Tower_Defense/?snr=1_7_7_151_150_1
# hello
# Legion TD 2 - Multiplayer Tower Defense
# Very Positive
# Nov 20, 2017
# ['Tower Defense', 'Strategy', 'Multiplayer', 'Competitive', 'Auto Battler', 'PvP', 'Online Co-Op', 'Co-op', 'Replay Value', 'Base Building', 'Resource Management', 'Indie', 'Early Access', 'Kickstarter', 'Fantasy', 'Sci-fi', 'Magic', 'Mechs', '3D', 'PvE']
# Legion TD 2 - Multiplayer Tower Defense
# Very Positive
# Nov 20, 2017
# None
# ['Tower Defense', 'Strategy', 'Multiplayer', 'Competitive', 'Auto Battler', 'PvP', 'Online Co-Op', 'Co-op', 'Replay Value', 'Base Building', 'Resource Management', 'Indie', 'Early Access', 'Kickstarter', 'Fantasy', 'Sci-fi', 'Magic', 'Mechs', '3D', 'PvE']
# https://store.steampowered.com/app/360170/How_to_Survive_2/?snr=1_7_7_151_150_1
# hello
# How to Survive 2
# Sep 8, 2016
# ['Survival', 'Zombies', 'Multiplayer', 'Open World Survival Craft', 'Open World', 'Crafting', 'Co-op', 'RPG', 'Adventure', 'Action', 'Base Building', 'Local Co-Op', 'Singleplayer', 'Third Person', 'Gore', 'Shooter', 'Early Access', 'Top-Down Shooter', '4 Player Local', 'Dark Humor']
# How to Survive 2
# None
# Sep 8, 2016
# None
# ['Survival', 'Zombies', 'Multiplayer', 'Open World Survival Craft', 'Open World', 'Crafting', 'Co-op', 'RPG', 'Adventure', 'Action', 'Base Building', 'Local Co-Op', 'Singleplayer', 'Third Person', 'Gore', 'Shooter', 'Early Access', 'Top-Down Shooter', '4 Player Local', 'Dark Humor']
# https://store.steampowered.com/app/453690/Dark_Quest_2/?snr=1_7_7_151_150_1
# hello
# Dark Quest 2
# Mostly Positive
# Mar 6, 2018
# ['RPG', 'Strategy', 'Indie', 'Turn-Based', 'Dungeon Crawler', 'Isometric', 'Board Game', 'Adventure', 'Singleplayer', 'Tactical', 'Multiplayer', 'Turn-Based Tactics', 'Fantasy', 'Great Soundtrack', 'Online Co-Op', 'Early Access', 'Local Multiplayer', 'Story Rich', 'Games Workshop', 'Local Co-Op']
# Dark Quest 2
# Mostly Positive
# Mar 6, 2018
# None
# ['RPG', 'Strategy', 'Indie', 'Turn-Based', 'Dungeon Crawler', 'Isometric', 'Board Game', 'Adventure', 'Singleplayer', 'Tactical', 'Multiplayer', 'Turn-Based Tactics', 'Fantasy', 'Great Soundtrack', 'Online Co-Op', 'Early Access', 'Local Multiplayer', 'Story Rich', 'Games Workshop', 'Local Co-Op']
# https://store.steampowered.com/app/554390/How_To_Survive_2__Dead_Dynamite/?snr=1_7_7_151_150_1
# hello
# How To Survive 2 - Dead Dynamite
# Very Positive
# Nov 17, 2016
# ['Action', 'Adventure', 'RPG', 'Gore', 'Violent']
# How To Survive 2 - Dead Dynamite
# Very Positive
# Nov 17, 2016
# None
# ['Action', 'Adventure', 'RPG', 'Gore', 'Violent']
# https://store.steampowered.com/app/768520/The_Red_Solstice_2_Survivors/?snr=1_7_7_151_150_1
# hello
# The Red Solstice 2: Survivors
# 2021
# ['Strategy RPG', 'Real Time Tactics', 'Character Customization', 'Procedural Generation', 'Third Person', 'Zombies', 'Team-Based', 'RPG', 'Sci-fi', 'Strategy', 'Atmospheric', 'Aliens', 'Futuristic', 'Co-op', 'Singleplayer', 'Multiplayer', 'Online Co-Op', 'Tactical', 'Action', 'RTS']
# The Red Solstice 2: Survivors
# None
# 2021
# None
# ['Strategy RPG', 'Real Time Tactics', 'Character Customization', 'Procedural Generation', 'Third Person', 'Zombies', 'Team-Based', 'RPG', 'Sci-fi', 'Strategy', 'Atmospheric', 'Aliens', 'Futuristic', 'Co-op', 'Singleplayer', 'Multiplayer', 'Online Co-Op', 'Tactical', 'Action', 'RTS']
# https://store.steampowered.com/app/987490/DOKA_2_GUTS_OUT_NINJA/?snr=1_7_7_151_150_1
# hello
# DOKA 2 GUTS OUT NINJA
# Dec 27, 2018
# ['Action', 'Indie', 'Gore', 'Nudity', 'Top-Down Shooter', 'Arena Shooter', 'Casual', 'Shooter', 'Difficult', 'Survival', 'Violent', 'Top-Down', 'Mature', 'Funny', 'Singleplayer', 'Addictive', 'Trading', 'Memes', 'Simulation', 'Zombies']
# DOKA 2 GUTS OUT NINJA
# None
# Dec 27, 2018
# None
# ['Action', 'Indie', 'Gore', 'Nudity', 'Top-Down Shooter', 'Arena Shooter', 'Casual', 'Shooter', 'Difficult', 'Survival', 'Violent', 'Top-Down', 'Mature', 'Funny', 'Singleplayer', 'Addictive', 'Trading', 'Memes', 'Simulation', 'Zombies']
# https://store.steampowered.com/app/543192/How_To_Survive_2__Elite_Soldier_Skin_Pack/?snr=1_7_7_151_150_1
# hello
# How To Survive 2 - Elite Soldier Skin Pack
# Very Positive
# Oct 27, 2016
# ['Action', 'Adventure', 'RPG']
# How To Survive 2 - Elite Soldier Skin Pack
# Very Positive
# Oct 27, 2016
# None
# ['Action', 'Adventure', 'RPG']
# https://store.steampowered.com/app/543191/How_To_Survive_2__Musketeer_Skin_Pack/?snr=1_7_7_151_150_1
# hello
# How To Survive 2 - Musketeer Skin Pack
# Positive
# Oct 27, 2016
# ['Action', 'Adventure', 'RPG']
# How To Survive 2 - Musketeer Skin Pack
# Positive
# Oct 27, 2016
# None
# ['Action', 'Adventure', 'RPG']
# https://store.steampowered.com/app/543193/How_To_Survive_2__Norse_God_Skin_Pack/?snr=1_7_7_151_150_1
# hello
# How To Survive 2 - Norse God Skin Pack
# Positive
# Oct 27, 2016
# ['Action', 'Adventure', 'RPG']
# How To Survive 2 - Norse God Skin Pack
# Positive
# Oct 27, 2016
# None
# ['Action', 'Adventure', 'RPG']
# https://store.steampowered.com/app/543190/How_To_Survive_2__Pirates_of_the_Bayou_Skin_Pack/?snr=1_7_7_151_150_1
# hello
# How To Survive 2 - Pirates of the Bayou Skin Pack
# Positive
# Oct 27, 2016
# ['Action', 'Adventure', 'RPG']
# How To Survive 2 - Pirates of the Bayou Skin Pack
# Positive
# Oct 27, 2016
# None
# ['Action', 'Adventure', 'RPG']
# https://store.steampowered.com/app/378041/Warhammer_40000_Dawn_of_War_II__Retribution__The_Last_Stand_Necron_Overlord/?snr=1_7_7_151_150_1
# hello
# Warhammer® 40,000™: Dawn of War® II - Retribution - The Last Stand Necron Overlord
# Mar 15, 2016
# ['Strategy', 'Warhammer 40K']
# Warhammer® 40,000™: Dawn of War® II - Retribution - The Last Stand Necron Overlord
# None
# Mar 15, 2016
# None
# ['Strategy', 'Warhammer 40K']
# https://store.steampowered.com/app/1197440/Broken_Spell_2/?snr=1_7_7_151_150_1
# hello
# Broken Spell 2
# Feb 10, 2020
# ['Action', 'RPG', 'Indie', 'Adventure', 'Sexual Content', 'Nudity', 'Casual', 'Mature', 'Massively Multiplayer', 'Strategy', 'Simulation', 'Racing', 'Sports', 'Violent', 'Gore', 'Free to Play', 'Horror', 'Fighting', 'Open World', 'Puzzle']
# Broken Spell 2
# None
# Feb 10, 2020
# None
# ['Action', 'RPG', 'Indie', 'Adventure', 'Sexual Content', 'Nudity', 'Casual', 'Mature', 'Massively Multiplayer', 'Strategy', 'Simulation', 'Racing', 'Sports', 'Violent', 'Gore', 'Free to Play', 'Horror', 'Fighting', 'Open World', 'Puzzle']
# https://store.steampowered.com/app/475132/How_To_Survive_2__Teddy_Bear_Helmet/?snr=1_7_7_151_150_1
# hello
# How To Survive 2 - Teddy Bear Helmet
# Positive
# Sep 7, 2016
# ['Action', 'Adventure', 'RPG']
# How To Survive 2 - Teddy Bear Helmet
# Positive
# Sep 7, 2016
# None
# ['Action', 'Adventure', 'RPG']
# https://store.steampowered.com/app/475131/How_To_Survive_2__Crow_Pet/?snr=1_7_7_151_150_1
# hello
# How To Survive 2 - Crow Pet
# Positive
# Sep 7, 2016
# ['RPG', 'Action', 'Adventure']
# How To Survive 2 - Crow Pet
# Positive
# Sep 7, 2016
# None
# ['RPG', 'Action', 'Adventure']
# https://store.steampowered.com/bundle/9846/PC_Caf_Essentials_F2P/?snr=1_7_7_151_150_1
# hello
# 'NoneType' object has no attribute 'get_text'
# None
# None
# None
# None
# None
# https://store.steampowered.com/app/687630/Epic_Cards_Battle_2_TCG/?snr=1_7_7_151_150_1
# hello
# Epic Cards Battle 2 (TCG)
# Oct 10, 2019
# ['Free to Play', 'Strategy', 'Casual', 'Adventure', 'Card Game', 'Nudity']
# Epic Cards Battle 2 (TCG)
# None
# Oct 10, 2019
# None
# ['Free to Play', 'Strategy', 'Casual', 'Adventure', 'Card Game', 'Nudity']
# https://store.steampowered.com/app/475130/How_To_Survive_2__Combat_Knives/?snr=1_7_7_151_150_1
# hello
# How To Survive 2 - Combat Knives
# Mostly Positive
# Sep 7, 2016
# ['Action', 'RPG', 'Adventure']
# How To Survive 2 - Combat Knives
# Mostly Positive
# Sep 7, 2016
# None
# ['Action', 'RPG', 'Adventure']
# https://store.steampowered.com/app/1418020/Tavern_of_Gods/?snr=1_7_7_151_150_1
# hello
# Tavern of Gods
# Mostly Positive
# Dec 3, 2020
# ['Early Access', 'Indie', 'Roguelite', 'Replay Value', 'Auto Battler', 'Roguelike', 'Strategy', 'Choices Matter', 'Creature Collector', 'Deckbuilding', 'Party-Based RPG', 'Magic', 'Fantasy', 'Singleplayer', 'Casual', 'Traditional Roguelike', 'Action', 'Adventure', 'Demons', 'Mythology']
# Tavern of Gods
# Mostly Positive
# Dec 3, 2020
# None
# ['Early Access', 'Indie', 'Roguelite', 'Replay Value', 'Auto Battler', 'Roguelike', 'Strategy', 'Choices Matter', 'Creature Collector', 'Deckbuilding', 'Party-Based RPG', 'Magic', 'Fantasy', 'Singleplayer', 'Casual', 'Traditional Roguelike', 'Action', 'Adventure', 'Demons', 'Mythology']
# https://store.steampowered.com/app/100980/3DCoat_49/?snr=1_7_7_151_150_1
# hello
# 3DCoat 4.9
# Very Positive
# Oct 2, 2012
# ['Animation & Modeling', 'Education', 'Design & Illustration', 'Utilities', 'Game Development', 'Photo Editing']
# 3DCoat 4.9
# Very Positive
# Oct 2, 2012
# None
# ['Animation & Modeling', 'Education', 'Design & Illustration', 'Utilities', 'Game Development', 'Photo Editing']
# https://store.steampowered.com/app/390560/Fantasy_Strike/?snr=1_7_7_151_150_1
# hello
# Fantasy Strike
# Jul 25, 2019
# ['Free to Play', '2D Fighter', 'Fighting', 'Competitive', 'Indie', 'PvP', 'Multiplayer', 'Local Multiplayer', 'Singleplayer', 'Casual', 'Stylized', 'Colorful', 'Anime', 'Arcade', 'Fantasy', 'Martial Arts', 'Controller', 'Action', '3D', 'Fast-Paced']
# Fantasy Strike
# None
# Jul 25, 2019
# None
# ['Free to Play', '2D Fighter', 'Fighting', 'Competitive', 'Indie', 'PvP', 'Multiplayer', 'Local Multiplayer', 'Singleplayer', 'Casual', 'Stylized', 'Colorful', 'Anime', 'Arcade', 'Fantasy', 'Martial Arts', 'Controller', 'Action', '3D', 'Fast-Paced']
# https://store.steampowered.com/app/450390/The_Lab/?snr=1_7_7_151_150_1
# hello
# The Lab
# Very Positive
# Apr 5, 2016
# ['Free to Play', 'VR', 'Action', 'Singleplayer', 'First-Person', 'Adventure', 'Funny', 'Sandbox', 'Casual', 'Sci-fi', 'Family Friendly', 'FPS', 'Shooter', 'Memes', 'Strategy', 'Archery', 'Puzzle']
# The Lab
# Very Positive
# Apr 5, 2016
# None
# ['Free to Play', 'VR', 'Action', 'Singleplayer', 'First-Person', 'Adventure', 'Funny', 'Sandbox', 'Casual', 'Sci-fi', 'Family Friendly', 'FPS', 'Shooter', 'Memes', 'Strategy', 'Archery', 'Puzzle']
# https://store.steampowered.com/app/207730/Arena_Wars_2/?snr=1_7_7_151_150_1
# hello
# Arena Wars 2
# Oct 12, 2012
# ['Strategy', 'Action', 'RTS']
# Arena Wars 2
# None
# Oct 12, 2012
# None
# ['Strategy', 'Action', 'RTS']
# https://store.steampowered.com/app/584180/Dark_Quest_2_Soundtrack/?snr=1_7_7_151_150_1
# hello
# Dark Quest 2 Soundtrack
# Jan 21, 2017
# ['Strategy', 'RPG', 'Indie']
# Dark Quest 2 Soundtrack
# None
# Jan 21, 2017
# None
# ['Strategy', 'RPG', 'Indie']
# https://store.steampowered.com/app/245550/Free_to_Play/?snr=1_7_7_151_150_1
# hello
# Free to Play
# Overwhelmingly Positive
# Mar 19, 2014
# ['Free to Play', 'Documentary', 'eSports', 'Action RTS', 'Emotional', 'Epic', 'Beautiful', 'Drama', 'Feature Film', '2D']
# Free to Play
# Overwhelmingly Positive
# Mar 19, 2014
# None
# ['Free to Play', 'Documentary', 'eSports', 'Action RTS', 'Emotional', 'Epic', 'Beautiful', 'Drama', 'Feature Film', '2D']
# https://store.steampowered.com/app/1196700/Memory_Match_Saga__Expansion_Pack_2/?snr=1_7_7_151_150_1
# hello
# Memory Match Saga - Expansion Pack 2
# Nov 22, 2019
# ['Casual', 'Indie', 'Simulation', 'Strategy', 'Adventure']
# Memory Match Saga - Expansion Pack 2
# None
# Nov 22, 2019
# None
# ['Casual', 'Indie', 'Simulation', 'Strategy', 'Adventure']
# https://store.steampowered.com/bundle/232/Valve_Complete_Pack/?snr=1_7_7_151_150_1
# hello
# 'NoneType' object has no attribute 'get_text'
# None
# None
# None
# None
# None
# https://store.steampowered.com/app/1048100/Peekaboo_Hide_and_Seek/?snr=1_7_7_151_150_1
# hello
# Peekaboo: Hide and Seek
# Very Positive
# Aug 7, 2019
# ['RPG', 'Action', 'Indie', 'Casual', 'Multiplayer', 'Physics', 'Online Co-Op', 'PvP', 'Team-Based', 'Co-op', 'Anime', 'Hidden Object', 'Creature Collector', 'Strategy', 'Funny', 'Stealth', 'Colorful', 'Atmospheric', 'Family Friendly', 'Simulation']
# Peekaboo: Hide and Seek
# Very Positive
# Aug 7, 2019
# None
# ['RPG', 'Action', 'Indie', 'Casual', 'Multiplayer', 'Physics', 'Online Co-Op', 'PvP', 'Team-Based', 'Co-op', 'Anime', 'Hidden Object', 'Creature Collector', 'Strategy', 'Funny', 'Stealth', 'Colorful', 'Atmospheric', 'Family Friendly', 'Simulation']
# https://store.steampowered.com/app/977970/Artbook__Metal_Pass_2/?snr=1_7_7_151_150_1
# hello
# Artbook - Metal Pass 2
# ['Strategy', 'Action', 'Free to Play', 'Indie', 'Racing', 'Sports']
# Artbook - Metal Pass 2
# None
# None
# None
# ['Strategy', 'Action', 'Free to Play', 'Indie', 'Racing', 'Sports']
# https://store.steampowered.com/app/340170/FINAL_FANTASY_TYPE0_HD/?snr=1_7_7_151_150_1
# hello
# FINAL FANTASY TYPE-0™ HD
# Aug 18, 2015
# ['RPG', 'Action', 'JRPG', 'Fantasy', 'Story Rich', 'Great Soundtrack', 'Anime', 'Action RPG', 'Singleplayer', 'Adventure', 'Third Person', 'Hack and Slash', 'Open World', 'Nudity', 'Drama']
# FINAL FANTASY TYPE-0™ HD
# None
# Aug 18, 2015
# None
# ['RPG', 'Action', 'JRPG', 'Fantasy', 'Story Rich', 'Great Soundtrack', 'Anime', 'Action RPG', 'Singleplayer', 'Adventure', 'Third Person', 'Hack and Slash', 'Open World', 'Nudity', 'Drama']
# https://store.steampowered.com/app/406210/Over_the_Dream/?snr=1_7_7_151_150_1
# hello
# Over the Dream
# Very Positive
# Nov 6, 2015
# ['Documentary', 'Gaming', 'Movie']
# Over the Dream
# Very Positive
# Nov 6, 2015
# None
# ['Documentary', 'Gaming', 'Movie']
# https://store.steampowered.com/app/539730/True_Sight/?snr=1_7_7_151_150_1
# hello
# True Sight
# Very Positive
# Oct 14, 2016
# ['Documentary', 'Episodic', 'Gaming', 'Free to Play']
# True Sight
# Very Positive
# Oct 14, 2016
# None
# ['Documentary', 'Episodic', 'Gaming', 'Free to Play']
# https://store.steampowered.com/app/206500/AirMech_Strike/?snr=1_7_7_151_150_1
# hello
# AirMech Strike
# Mostly Positive
# Mar 30, 2018
# ['Free to Play', 'Strategy', 'Multiplayer', 'Mechs', 'MOBA', 'RTS', 'Action', 'Robots', 'Online Co-Op', 'Indie', 'Sci-fi', 'Co-op', 'PvP', 'Shooter', 'Massively Multiplayer', 'Early Access', 'Singleplayer', 'Adventure', 'Fast-Paced', 'RPG']
# AirMech Strike
# Mostly Positive
# Mar 30, 2018
# None
# ['Free to Play', 'Strategy', 'Multiplayer', 'Mechs', 'MOBA', 'RTS', 'Action', 'Robots', 'Online Co-Op', 'Indie', 'Sci-fi', 'Co-op', 'PvP', 'Shooter', 'Massively Multiplayer', 'Early Access', 'Singleplayer', 'Adventure', 'Fast-Paced', 'RPG']
# https://store.steampowered.com/app/583950/Artifact/?snr=1_7_7_151_150_1
# hello
# Artifact
# Nov 28, 2018
# ['Card Battler', 'Deckbuilding', 'Card Game', 'Trading Card Game', 'Strategy', 'Multiplayer', 'eSports', 'Tactical', 'Competitive', 'Difficult', 'Turn-Based Strategy', 'Fantasy', 'Singleplayer', 'Casual', 'Turn-Based', 'Great Soundtrack', 'Atmospheric', 'Magic', 'Funny', 'Violent']
# Artifact
# None
# Nov 28, 2018
# None
# ['Card Battler', 'Deckbuilding', 'Card Game', 'Trading Card Game', 'Strategy', 'Multiplayer', 'eSports', 'Tactical', 'Competitive', 'Difficult', 'Turn-Based Strategy', 'Fantasy', 'Singleplayer', 'Casual', 'Turn-Based', 'Great Soundtrack', 'Atmospheric', 'Magic', 'Funny', 'Violent']
# https://store.steampowered.com/app/250400/How_to_Survive/?snr=1_7_7_151_150_1
# hello
# How to Survive
# Mostly Positive
# Oct 23, 2013
# ['Survival', 'Zombies', 'Crafting', 'Open World Survival Craft', 'Action', 'Co-op', 'Multiplayer', 'RPG', 'Local Co-Op', 'Online Co-Op', 'Adventure', 'Survival Horror', 'Open World', 'Hack and Slash', 'Post-apocalyptic', 'Singleplayer', 'Third Person', 'Gore', 'Comedy', 'Indie']
# How to Survive
# Mostly Positive
# Oct 23, 2013
# None
# ['Survival', 'Zombies', 'Crafting', 'Open World Survival Craft', 'Action', 'Co-op', 'Multiplayer', 'RPG', 'Local Co-Op', 'Online Co-Op', 'Adventure', 'Survival Horror', 'Open World', 'Hack and Slash', 'Post-apocalyptic', 'Singleplayer', 'Third Person', 'Gore', 'Comedy', 'Indie']
# https://store.steampowered.com/app/216172/AirMech_Strike_Pack/?snr=1_7_7_151_150_1
# hello
# AirMech Strike Pack
# Positive
# Oct 5, 2012
# ['Strategy', 'Indie', 'Free to Play']
# AirMech Strike Pack
# Positive
# Oct 5, 2012
# None
# ['Strategy', 'Indie', 'Free to Play']
# https://store.steampowered.com/app/438480/Rock_N_Roll_Defense/?snr=1_7_7_151_150_1
# hello
# Rock 'N' Roll Defense
# Very Positive
# Aug 10, 2016
# ['Tower Defense', 'Casual', 'Strategy', 'Adventure', 'Great Soundtrack', 'Indie', 'Action', 'Music', '2D', 'Singleplayer', 'Retro', 'Replay Value', 'Soundtrack', 'Touch-Friendly', 'Tactical', 'Comedy', 'Classic', 'Old School', 'GameMaker', '1980s']
# Rock 'N' Roll Defense
# Very Positive
# Aug 10, 2016
# None
# ['Tower Defense', 'Casual', 'Strategy', 'Adventure', 'Great Soundtrack', 'Indie', 'Action', 'Music', '2D', 'Singleplayer', 'Retro', 'Replay Value', 'Soundtrack', 'Touch-Friendly', 'Tactical', 'Comedy', 'Classic', 'Old School', 'GameMaker', '1980s']
# https://store.steampowered.com/app/1171040/Eonica_Chess_Battle/?snr=1_7_7_151_150_1
# hello
# Eonica Chess Battle
# Positive
# Oct 31, 2020
# ['Auto Battler', 'Free to Play', 'Early Access', 'Casual', 'Strategy', 'Management', 'Board Game', 'Multiplayer', 'Singleplayer', 'Chess', '3D', 'Stylized', 'Top-Down', 'Turn-Based Tactics', 'Economy', 'Fantasy', 'Turn-Based Combat', 'Combat', 'PvP', 'Magic']
# Eonica Chess Battle
# Positive
# Oct 31, 2020
# None
# ['Auto Battler', 'Free to Play', 'Early Access', 'Casual', 'Strategy', 'Management', 'Board Game', 'Multiplayer', 'Singleplayer', 'Chess', '3D', 'Stylized', 'Top-Down', 'Turn-Based Tactics', 'Economy', 'Fantasy', 'Turn-Based Combat', 'Combat', 'PvP', 'Magic']
# https://store.steampowered.com/app/391580/Egyptian_Senet/?snr=1_7_7_151_150_1
# hello
# Egyptian Senet
# Very Positive
# Aug 21, 2015
# ['Board Game', 'Historical', 'Tabletop', 'Mythology', 'Strategy', 'Casual', 'Chess', 'Solitaire', 'Relaxing', 'Family Friendly', 'Indie', 'Simulation', 'Puzzle', 'Arcade', 'Clicker', 'Underground', 'Education', 'Life Sim', 'Turn-Based', 'Mystery']
# Egyptian Senet
# Very Positive
# Aug 21, 2015
# None
# ['Board Game', 'Historical', 'Tabletop', 'Mythology', 'Strategy', 'Casual', 'Chess', 'Solitaire', 'Relaxing', 'Family Friendly', 'Indie', 'Simulation', 'Puzzle', 'Arcade', 'Clicker', 'Underground', 'Education', 'Life Sim', 'Turn-Based', 'Mystery']
# https://store.steampowered.com/app/399640/Flamebreak/?snr=1_7_7_151_150_1
# hello
# Flamebreak
# Very Positive
# Mar 15, 2016
# ['Indie', 'RPG', 'Action Roguelike', 'Roguelite', 'Replay Value', 'Procedural Generation', 'Roguelike', 'Action', 'Twin Stick Shooter']
# Flamebreak
# Very Positive
# Mar 15, 2016
# None
# ['Indie', 'RPG', 'Action Roguelike', 'Roguelite', 'Replay Value', 'Procedural Generation', 'Roguelike', 'Action', 'Twin Stick Shooter']
# https://store.steampowered.com/app/336420/BloodsportsTV/?snr=1_7_7_151_150_1
# hello
# Bloodsports.TV
# Very Positive
# Mar 30, 2015
# ['Action', 'Indie', 'Hack and Slash', 'MOBA', 'Post-apocalyptic', 'Survival', 'Co-op', 'PvE', 'Adventure', 'Strategy', 'Casual', 'Sports', 'Multiplayer', 'Singleplayer', 'Tower Defense', 'Funny', 'Free to Play', 'RTS', 'Massively Multiplayer', 'Animation & Modeling']
# Bloodsports.TV
# Very Positive
# Mar 30, 2015
# None
# ['Action', 'Indie', 'Hack and Slash', 'MOBA', 'Post-apocalyptic', 'Survival', 'Co-op', 'PvE', 'Adventure', 'Strategy', 'Casual', 'Sports', 'Multiplayer', 'Singleplayer', 'Tower Defense', 'Funny', 'Free to Play', 'RTS', 'Massively Multiplayer', 'Animation & Modeling']
# https://store.steampowered.com/app/1241100/POLYGON_Multiplayer_Shooter/?snr=1_7_7_151_150_1
# hello
# POLYGON: Multiplayer Shooter
# Mar 6, 2020
# ['Free to Play', 'Shooter', 'Action', 'FPS', 'Multiplayer', 'Online Co-Op', 'Massively Multiplayer', 'Military', 'Indie', 'War', 'Early Access', 'Tactical', 'Co-op', 'Wargame', '3D', 'Anime', 'Voxel', 'Isometric', 'Minimalist', 'Cute']
# POLYGON: Multiplayer Shooter
# None
# Mar 6, 2020
# None
# ['Free to Play', 'Shooter', 'Action', 'FPS', 'Multiplayer', 'Online Co-Op', 'Massively Multiplayer', 'Military', 'Indie', 'War', 'Early Access', 'Tactical', 'Co-op', 'Wargame', '3D', 'Anime', 'Voxel', 'Isometric', 'Minimalist', 'Cute']
# https://store.steampowered.com/app/878940/Collective_the_Community_Created_Card_Game/?snr=1_7_7_151_150_1
# hello
# Collective: the Community Created Card Game
# Very Positive
# Mar 27, 2020
# ['Free to Play', 'Strategy', 'Indie', 'Card Game', 'Early Access', 'Multiplayer', 'Moddable', 'Roguelite', 'Trading Card Game', 'Singleplayer']
# Collective: the Community Created Card Game
# Very Positive
# Mar 27, 2020
# None
# ['Free to Play', 'Strategy', 'Indie', 'Card Game', 'Early Access', 'Multiplayer', 'Moddable', 'Roguelite', 'Trading Card Game', 'Singleplayer']
# https://store.steampowered.com/app/1102370/Dr_Derks_Mutant_Battlegrounds/?snr=1_7_7_151_150_1
# hello
# Dr. Derk's Mutant Battlegrounds
# Positive
# Jul 28, 2020
# ['Early Access', 'Artificial Intelligence', 'Auto Battler', 'Strategy', 'MOBA', 'Indie', 'PvP', 'Management', 'Action', 'Massively Multiplayer', 'Multiplayer', 'Asynchronous Multiplayer', 'Singleplayer', 'Minimalist', 'Stylized', 'Top-Down', 'Western', 'Dinosaurs', 'Funny', 'Cartoony']
# Dr. Derk's Mutant Battlegrounds
# Positive
# Jul 28, 2020
# None
# ['Early Access', 'Artificial Intelligence', 'Auto Battler', 'Strategy', 'MOBA', 'Indie', 'PvP', 'Management', 'Action', 'Massively Multiplayer', 'Multiplayer', 'Asynchronous Multiplayer', 'Singleplayer', 'Minimalist', 'Stylized', 'Top-Down', 'Western', 'Dinosaurs', 'Funny', 'Cartoony']
# https://store.steampowered.com/app/202710/Demigod/?snr=1_7_7_151_150_1
# hello
# Demigod
# Mostly Positive
# Dec 14, 2011
# ['Real Time Tactics', 'MOBA', 'PvP', 'PvE', 'RTS', 'Character Customization', 'Strategy', 'Third Person', '3D', 'Team-Based', 'Sandbox', 'Fantasy', 'Tactical', 'Magic', 'Action', 'Mythology', 'War', 'Atmospheric', 'Cinematic', 'Beautiful']
# Demigod
# Mostly Positive
# Dec 14, 2011
# None
# ['Real Time Tactics', 'MOBA', 'PvP', 'PvE', 'RTS', 'Character Customization', 'Strategy', 'Third Person', '3D', 'Team-Based', 'Sandbox', 'Fantasy', 'Tactical', 'Magic', 'Action', 'Mythology', 'War', 'Atmospheric', 'Cinematic', 'Beautiful']
# https://store.steampowered.com/search/?sort_by=&sort_order=0&term=dota%202&page=2
# hello
# 'NoneType' object has no attribute 'get_text'
# None
# None
# None
# None
# None
# https://store.steampowered.com/search/?sort_by=&sort_order=0&term=dota%202&page=3
# hello
# 'NoneType' object has no attribute 'get_text'
# None
# None
# None
# None
# None
# https://store.steampowered.com/search/?sort_by=&sort_order=0&term=dota%202&page=2
# hello
# 'NoneType' object has no attribute 'get_text'
# None
# None
# None
# None
# None
# Invalid URL '#': No schema supplied. Perhaps you meant http://#?
# Invalid URL '#': No schema supplied. Perhaps you meant http://#?
# Invalid URL '#': No schema supplied. Perhaps you meant http://#?
# Invalid URL '#': No schema supplied. Perhaps you meant http://#?
# Invalid URL '#': No schema supplied. Perhaps you meant http://#?
# https://support.steampowered.com/kb_article.php?p_faqid=549#gifts
# hello
# 'NoneType' object has no attribute 'get_text'
# None
# None
# None
# None
# None
# https://steamcommunity.com/?snr=1_44_44__22
# hello
# 'NoneType' object has no attribute 'get_text'
# None
# None
# None
# None
# None
# http://www.valvesoftware.com/about.html
# hello
# 'NoneType' object has no attribute 'get_text'
# None
# None
# None
# None
# None
# http://www.valvesoftware.com/business/
# hello
# 'NoneType' object has no attribute 'get_text'
# None
# None
# None
# None
# None
# http://www.steampowered.com/steamworks/
# hello
# 'NoneType' object has no attribute 'get_text'
# None
# None
# None
# None
# None
# http://www.valvesoftware.com/jobs.html
# hello
# 'NoneType' object has no attribute 'get_text'
# None
# None
# None
# None
# None
# https://help.steampowered.com/en/?snr=1_44_44__23
# hello
# 'NoneType' object has no attribute 'get_text'
# None
# None
# None
# None
# None
# https://store.steampowered.com/forums/?snr=1_44_44__23
# hello
# 'NoneType' object has no attribute 'get_text'
# None
# None
# None
# None
# None
# https://store.steampowered.com/stats/?snr=1_44_44__23
# hello
# 'NoneType' object has no attribute 'get_text'
# None
# None
# None
# None
# None
# https://store.steampowered.com/feeds/news.xml
# hello
# 'NoneType' object has no attribute 'get_text'
# None
# None
# None
# None
# None
# https://store.steampowered.com/feeds/newreleases.xml
# hello
# 'NoneType' object has no attribute 'get_text'
# None
# None
# None
# None
# None
# https://store.steampowered.com/feeds/daily_deals.xml
# hello
# 'NoneType' object has no attribute 'get_text'
# None
# None
# None
# None
# None
# https://store.steampowered.com/privacy_agreement/?snr=1_44_44_
# hello
# 'NoneType' object has no attribute 'get_text'
# None
# None
# None
# None
# None
# https://store.steampowered.com/legal/?snr=1_44_44_
# hello
# 'NoneType' object has no attribute 'get_text'
# None
# None
# None
# None
# None
# https://store.steampowered.com/subscriber_agreement/?snr=1_44_44_
# hello
# 'NoneType' object has no attribute 'get_text'
# None
# None
# None
# None
# None
# https://store.steampowered.com/steam_refunds/?snr=1_44_44_
# hello
# 'NoneType' object has no attribute 'get_text'
# None
# None
# None
# None
# None
# http://www.valvesoftware.com/about.html
# hello
# 'NoneType' object has no attribute 'get_text'
# None
# None
# None
# None
# None
# http://www.steampowered.com/steamworks/
# hello
# 'NoneType' object has no attribute 'get_text'
# None
# None
# None
# None
# None
# http://www.valvesoftware.com/jobs.html
# hello
# 'NoneType' object has no attribute 'get_text'
# None
# None
# None
# None
# None
# https://partner.steamgames.com/steamdirect
# hello
# 'NoneType' object has no attribute 'get_text'
# None
# None
# None
# None
# None
# https://store.steampowered.com/digitalgiftcards/?snr=1_44_44_
# hello
# 'NoneType' object has no attribute 'get_text'
# None
# None
# None
# None
# None
# https://steamcommunity.com/linkfilter/?url=http://www.facebook.com/Steam
# hello
# 'NoneType' object has no attribute 'get_text'
# None
# None
# None
# None
# None
# http://twitter.com/steam
# hello
# 'NoneType' object has no attribute 'get_text'
# None
# None
# None
# None
# None

# %%
steamtest = pd.read_csv('steam_data.csv', error_bad_lines=False)
# Out:
# b'Skipping line 5: expected 5 fields, saw 25\nSkipping line 7: expected 5 fields, saw 6\nSkipping line 9: expected 5 fields, saw 10\nSkipping line 11: expected 5 fields, saw 19\nSkipping line 13: expected 5 fields, saw 23\nSkipping line 15: expected 5 fields, saw 12\nSkipping line 17: expected 5 fields, saw 25\nSkipping line 19: expected 5 fields, saw 25\nSkipping line 21: expected 5 fields, saw 25\nSkipping line 23: expected 5 fields, saw 10\nSkipping line 25: expected 5 fields, saw 24\nSkipping line 27: expected 5 fields, saw 25\nSkipping line 29: expected 5 fields, saw 8\nSkipping line 31: expected 5 fields, saw 8\nSkipping line 33: expected 5 fields, saw 8\nSkipping line 35: expected 5 fields, saw 8\nSkipping line 37: expected 5 fields, saw 8\nSkipping line 39: expected 5 fields, saw 25\nSkipping line 41: expected 5 fields, saw 8\nSkipping line 43: expected 5 fields, saw 8\nSkipping line 47: expected 5 fields, saw 11\nSkipping line 49: expected 5 fields, saw 8\nSkipping line 51: expected 5 fields, saw 25\nSkipping line 53: expected 5 fields, saw 11\nSkipping line 55: expected 5 fields, saw 25\nSkipping line 57: expected 5 fields, saw 22\nSkipping line 59: expected 5 fields, saw 8\nSkipping line 61: expected 5 fields, saw 8\nSkipping line 63: expected 5 fields, saw 15\nSkipping line 65: expected 5 fields, saw 10\nSkipping line 69: expected 5 fields, saw 25\nSkipping line 71: expected 5 fields, saw 10\nSkipping line 73: expected 5 fields, saw 20\nSkipping line 75: expected 5 fields, saw 8\nSkipping line 77: expected 5 fields, saw 9\nSkipping line 79: expected 5 fields, saw 25\nSkipping line 81: expected 5 fields, saw 25\nSkipping line 83: expected 5 fields, saw 25\nSkipping line 85: expected 5 fields, saw 8\nSkipping line 87: expected 5 fields, saw 25\nSkipping line 89: expected 5 fields, saw 25\nSkipping line 91: expected 5 fields, saw 25\nSkipping line 93: expected 5 fields, saw 14\nSkipping line 95: expected 5 fields, saw 25\nSkipping line 97: expected 5 fields, saw 25\nSkipping line 99: expected 5 fields, saw 15\nSkipping line 101: expected 5 fields, saw 25\nSkipping line 103: expected 5 fields, saw 25\n'

# %%
df = pd.read_csv('test_file.TXT')

# %%
df = df.iloc[115:]

# %%
df.reset_index(drop=True, inplace=True)

# %%
#df[df['https://store.steampowered.com/login/?redir=search%2F%3Fterm%3Ddota%2B2&redir_ssl=1&snr=1_7_7_151_global-header'] == '#']
df.drop(58, inplace = True)

# %%
df['https://store.steampowered.com/login/?redir=search%2F%3Fterm%3Ddota%2B2&redir_ssl=1&snr=1_7_7_151_global-header']
# Out:
# 0     https://store.steampowered.com/app/570/Dota_2/...
# 1     https://store.steampowered.com/app/1241930/The...
# 2     https://store.steampowered.com/app/652720/The_...
# 3     https://store.steampowered.com/app/411180/Dota...
# 4     https://store.steampowered.com/app/1018830/Ele...
#                             ...
# 77               http://www.valvesoftware.com/jobs.html
# 78           https://partner.steamgames.com/steamdirect
# 79    https://store.steampowered.com/digitalgiftcard...
# 80    https://steamcommunity.com/linkfilter/?url=htt...
# 81                             http://twitter.com/steam
# Name: https://store.steampowered.com/login/?redir=search%2F%3Fterm%3Ddota%2B2&redir_ssl=1&snr=1_7_7_151_global-header, Length: 81, dtype: object

# %%
df.reset_index(drop=True, inplace = True)

# %%
df2 = pd.read_csv('dota2_info.TXT')

# %%
df2
# Out:
#      M
# 0    o
# 1    s
# 2    t
# 3    l
# 4    y
# ..  ..
# 404  i
# 405  t
# 406  i
# 407  v
# 408  e
#
# [409 rows x 1 columns]
